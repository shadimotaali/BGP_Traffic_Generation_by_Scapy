# %%
# Step 1: Change to the directory where you want to clone the repository
import os
target_dir = "/Users/shadimoteali/PhD/BGP_Traffic_Generation"

# Check if we have write permissions to this directory
if os.access(target_dir, os.W_OK):
    print(f"We have write access to {target_dir}")
else:
    print(f"WARNING: No write access to {target_dir}")

# Step 2: Clone the repository to the specified directory
# !cd {target_dir} && git clone https://github.com/toonst/pcap2scapy.git
# Out:
# We have write access to /Users/shadimoteali/PhD/BGP_Traffic_Generation
# Cloning into 'pcap2scapy'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 17 (delta 6), reused 15 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (17/17), 9.43 KiB | 9.43 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# Step 3: Run pcap2scapy from the cloned repository
pcap_file = "/Users/shadimoteali/PhD/BGP_Traffic_Generation/pcaps/realistic_bgp_complete_scenarios.pcap"  # Update this path
output_path = "/Users/shadimoteali/PhD/BGP_Traffic_Generation/pcap2scapy_result/output_file.py"
# !python /Users/shadimoteali/PhD/BGP_Traffic_Generation/pcap2scapy/pcap2scapy.py {pcap_file} -o {output_path}
# Out:
# WARNING: [bgp.py] use_2_bytes_asn: True
# Created /Users/shadimoteali/PhD/BGP_Traffic_Generation/pcap2scapy_result/output_file.py (1132 packets).
# Run with, e.g.:
#   sudo python /Users/shadimoteali/PhD/BGP_Traffic_Generation/pcap2scapy_result/output_file.py -i eth0
